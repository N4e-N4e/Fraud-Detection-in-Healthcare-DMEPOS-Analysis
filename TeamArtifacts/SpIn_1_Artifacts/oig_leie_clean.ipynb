# %% [markdown]
# # Cleaning the LEIE List
#
# This takes the raw data file from the OIG website on the most recent exclusions list.
#
# The original data can have multiple rows per entity based on differences in name descriptions, different locations, different exclusion dates, and different exclusion types.
#
# Data Cleaning Steps:
# - Change all data to columns to snake case
# - Change the data types of specified columns
# - Drop blank columns
# - Keep only the most recent name descriptions for each npi
# - filter dataset on exclusion date greater than 2020
# - filter dataset on specified exclusion types (the crosswalk and definition of each exclusion type is in our teams Capstone folder
# - filter dataset on most recent exclusion only to get 1 per row
#
# Additional Columns
# - Add column for number of exclusion dates
# - Add column for number of unique exclusions
# - Add column for list of unique exclusions
# - Add column for number of unique addresses
# - fraud_flag which is 1 for all rows
#
# Return a dataset that has null NPIs to possibly backfill later. ("/dsa/groups/casestudycf25/team02/leie_with_null_npi_clean.csv", index=False)
#
# Return clean dataset of only valid NPIs and exclusion dates greater than 2020
# /dsa/groups/casestudycf25/team02/leie_with_valid_npi_clean.csv

# %%
# Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Change all headers to snake case
import re

def to_snake_case(name: str) -> str:
    # Add underscore between lower-to-upper transitions
    name = re.sub(r'(.)([A-Z][a-z]+)', r'\1_\2', name)
    name = re.sub(r'([a-z0-9])([A-Z])', r'\1_\2', name)

    # Replace non-alphanumeric with underscores
    name = re.sub(r'[^0-9a-zA-Z]+', '_', name)

    # Remove leading/trailing underscores and lowercase
    return name.strip("_").lower()

# %%
# Read in CSV from file path
df = pd.read_csv("/dsa/groups/casestudycf25/team02/LEIE_OIG_Exclusion_List.csv")

df = df.rename(columns={col: to_snake_case(col) for col in df.columns})

df.head(5)
# Out:
# /tmp/ipykernel_8038/342442810.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/dsa/groups/casestudycf25/team02/LEIE_OIG_Exclusion_List.csv")
#   lastname firstname midname                      busname         general  \
# 0      NaN       NaN     NaN    #1 MARKETING SERVICE, INC  OTHER BUSINESS
# 1      NaN       NaN     NaN             1 BEST CARE, INC  OTHER BUSINESS
# 2      NaN       NaN     NaN  101 FIRST CARE PHARMACY INC  OTHER BUSINESS
# 3      NaN       NaN     NaN     14 LAWRENCE AVE PHARMACY        PHARMACY
# 4      NaN       NaN     NaN     143 MEDICAL EQUIPMENT CO     DME COMPANY
#
#             specialty upin         npi  dob                        address  \
# 0          SOBER HOME  NaN           0  NaN      239 BRIGHTON BEACH AVENUE
# 1  HOME HEALTH AGENCY  NaN           0  NaN  2161 UNIVERSITY AVENUE W, STE
# 2            PHARMACY  NaN  1972902351  NaN  C/O 609 W 191ST STREET, APT D
# 3                 NaN  NaN           0  NaN             14 LAWRENCE AVENUE
# 4        DME - OXYGEN  NaN           0  NaN               701 NW 36 AVENUE
#
#          city state    zip excltype  excldate  reindate  waiverdate wvrstate
# 0    BROOKLYN    NY  11235   1128a1  20200319         0           0      NaN
# 1  SAINT PAUL    MN  55114   1128b5  20230518         0           0      NaN
# 2    NEW YORK    NY  10040   1128b8  20220320         0           0      NaN
# 3   SMITHTOWN    NY  11787   1128a1  19880830         0           0      NaN
# 4       MIAMI    FL  33125   1128b7  19970620         0           0      NaN

# %%
print(f"Original Dataset Shape: {df.shape}")
# Out:
# Original Dataset Shape: (81991, 18)

# %%
# Drop blank columns
df.drop(columns = ['reindate', 'waiverdate', 'wvrstate'], inplace = True) # drop blank columns

# %%
# Convert npi
df['npi'] = df['npi'].replace(0, np.nan)

# %%
df.dtypes
# Out:
# lastname      object
# firstname     object
# midname       object
# busname       object
# general       object
# specialty     object
# upin          object
# npi          float64
# dob          float64
# address       object
# city          object
# state         object
# zip            int64
# excltype      object
# excldate       int64
# dtype: object

# %%
df.head(5)
# Out:
#   lastname firstname midname                      busname         general  \
# 0      NaN       NaN     NaN    #1 MARKETING SERVICE, INC  OTHER BUSINESS
# 1      NaN       NaN     NaN             1 BEST CARE, INC  OTHER BUSINESS
# 2      NaN       NaN     NaN  101 FIRST CARE PHARMACY INC  OTHER BUSINESS
# 3      NaN       NaN     NaN     14 LAWRENCE AVE PHARMACY        PHARMACY
# 4      NaN       NaN     NaN     143 MEDICAL EQUIPMENT CO     DME COMPANY
#
#             specialty upin           npi  dob                        address  \
# 0          SOBER HOME  NaN           NaN  NaN      239 BRIGHTON BEACH AVENUE
# 1  HOME HEALTH AGENCY  NaN           NaN  NaN  2161 UNIVERSITY AVENUE W, STE
# 2            PHARMACY  NaN  1.972902e+09  NaN  C/O 609 W 191ST STREET, APT D
# 3                 NaN  NaN           NaN  NaN             14 LAWRENCE AVENUE
# 4        DME - OXYGEN  NaN           NaN  NaN               701 NW 36 AVENUE
#
#          city state    zip excltype  excldate
# 0    BROOKLYN    NY  11235   1128a1  20200319
# 1  SAINT PAUL    MN  55114   1128b5  20230518
# 2    NEW YORK    NY  10040   1128b8  20220320
# 3   SMITHTOWN    NY  11787   1128a1  19880830
# 4       MIAMI    FL  33125   1128b7  19970620

# %% [markdown]
# ## Add Additional Feature Columns

# %%
# Add column for number of exclusion dates
df["num_exclusions_alltime"] = df.groupby("npi")["excldate"].transform("nunique")

# %%
# Add column for number of unique exclusions
df["num_exclusion_types_alltime"] = df.groupby("npi")["excltype"].transform("nunique")

# %%
# Add column for list of unique exclusions
type_map = df.groupby("npi")["excltype"].apply(lambda x: list(x.dropna().unique()))
df["list_exclusion_types_alltime"] = df["npi"].map(type_map)

# %%
# Add column for number of unique addresses
df["num_addresses_alltime"] = df.groupby("npi")["address"].transform("nunique")

# %%
# Convert to datetime
df["excldate"] = pd.to_datetime(df["excldate"], format="%Y%m%d", errors="coerce")
df["dob"] = pd.to_datetime(df["dob"], format="%Y%m%d", errors="coerce")

# %%
# Convert exclusion types to all lower case
df["excltype"] =  df["excltype"].str.lower()

# %%
df[df["num_exclusion_types_alltime"] > 2]
# Out:
#           lastname firstname midname busname               general  \
# 15950  CHRISTENSEN      JOHN   PETER     NaN    PHYSICIAN (MD, DO)
# 15951  CHRISTENSEN      JOHN     NaN     NaN    PHYSICIAN (MD, DO)
# 15952  CHRISTENSEN      JOHN   PETER     NaN    PHYSICIAN (MD, DO)
# 29223        GOINS     RONDY     NaN     NaN  IND- LIC HC SERV PRO
# 29224        GOINS     RONDY  DWAYNE     NaN  IND- LIC HC SERV PRO
# 29225        GOINS     RONDY  DWAYNE     NaN  IND- LIC HC SERV PRO
# 33166       HASPEL    ARTHUR    CARL     NaN     PODIATRY PRACTICE
# 33167       HASPEL    ARTHUR    CARL     NaN  IND- LIC HC SERV PRO
# 33168       HASPEL    ARTHUR    CARL     NaN     PODIATRY PRACTICE
#
#               specialty    upin           npi        dob  \
# 15950  GENERAL PRACTICE  K9897A  1.801839e+09 1951-09-25
# 15951  GENERAL PRACTICE  I53515  1.801839e+09 1951-09-25
# 15952  GENERAL PRACTICE     NaN  1.801839e+09 1951-09-25
# 29223          PODIATRY     NaN  1.508905e+09 1957-12-12
# 29224          PODIATRY  U19347  1.508905e+09 1957-12-12
# 29225          PODIATRY     NaN  1.508905e+09 1957-12-12
# 33166          PODIATRY  T55450  1.225072e+09 1945-05-18
# 33167          PODIATRY  T55450  1.225072e+09 1945-05-18
# 33168          PODIATRY  T55450  1.225072e+09 1945-05-18
#
#                             address             city state    zip excltype  \
# 15950           2900 N FLAGER DRIVE  WEST PALM BEACH    FL  33407   1128b4
# 15951                P O BOX 019120            MIAMI    FL  33101   1128a1
# 15952  568 NE 255TH STREET, #D63217       CROSS CITY    FL  32628   1128a2
# 29223      P O BOX 1000, #56760-039       MORGANTOWN    WV  26507   1128a1
# 29224     13201 VICTORIA PARK DR, N          DETROIT    MI  48215   1128b4
# 29225   13201 VICTORIA PARK DRIVE N          DETROIT    MI  48215  1128b14
# 33166  22949 OLD INLET BRIDGE DRIVE       BOCA RATON    FL  33433   1128a4
# 33167    P O BOX 779800, #30086-074            MIAMI    FL  33177   1128a1
# 33168   22949 OLD INLET BRIDGE ROAD       BOCA RATON    FL  33433   1128b7
#
#         excldate  num_exclusions_alltime  num_exclusion_types_alltime  \
# 15950 2013-11-20                     3.0                          3.0
# 15951 2017-05-18                     3.0                          3.0
# 15952 2019-02-20                     3.0                          3.0
# 29223 2023-05-18                     3.0                          3.0
# 29224 2013-02-20                     3.0                          3.0
# 29225 2018-12-20                     3.0                          3.0
# 33166 2003-07-20                     3.0                          3.0
# 33167 2012-05-20                     3.0                          3.0
# 33168 2010-09-01                     3.0                          3.0
#
#       list_exclusion_types_alltime  num_addresses_alltime
# 15950     [1128b4, 1128a1, 1128a2]                    3.0
# 15951     [1128b4, 1128a1, 1128a2]                    3.0
# 15952     [1128b4, 1128a1, 1128a2]                    3.0
# 29223    [1128a1, 1128b4, 1128b14]                    3.0
# 29224    [1128a1, 1128b4, 1128b14]                    3.0
# 29225    [1128a1, 1128b4, 1128b14]                    3.0
# 33166     [1128a4, 1128a1, 1128b7]                    3.0
# 33167     [1128a4, 1128a1, 1128b7]                    3.0
# 33168     [1128a4, 1128a1, 1128b7]                    3.0

# %%
# NPI Dimension

# Filter out null NAME values
npi_dim = df[df["npi"].notna()].copy()

# Sort by ID and DATE descending
npi_dim = npi_dim.sort_values(["npi", "excldate"], ascending=[True, False])

# Keep only the most recent name descriptions for each npi
npi_dim = npi_dim.groupby("npi").first().reset_index()

npi_dim = npi_dim[["npi", "lastname", "firstname", "midname", "busname"]]

npi_dim.head()
# Out:
#             npi  lastname firstname  midname busname
# 0  1.003005e+09     SMITH      ADAM   BRYANT    None
# 1  1.003012e+09      RICE  CHRISTAL     None    None
# 2  1.003017e+09  MARTINEZ  BENJAMIN     SETH    None
# 3  1.003028e+09  MESSERLY   RICHARD  CHARLES    None
# 4  1.003035e+09      WARD    SHARON  ROMAINE    None

# %%
npi_dim.dtypes
# Out:
# npi          float64
# lastname      object
# firstname     object
# midname       object
# busname       object
# dtype: object

# %%
df = df.merge(
    npi_dim[["npi", "lastname", "firstname", "midname", "busname"]],
    on="npi",
    how="left",
    suffixes=("", "_npi")
)

# %%
# Change the dataframe to use the dimension descriptions so that the text for the name columns are consistent across the data
df["lastname"]  = df["lastname_npi"].combine_first(df["lastname"])
df["firstname"] = df["firstname_npi"].combine_first(df["firstname"])
df["midname"]   = df["midname_npi"].combine_first(df["midname"])
df["busname"]   = df["busname_npi"].combine_first(df["busname"])

# %%
# Drop interim name descr columns
df = df.drop(columns=["lastname_npi", "firstname_npi", "midname_npi", "busname_npi"])

# %% [markdown]
# ## Filter the Dataset

# %%
###################################
# filter dataset on exclusion date greater than 2020
###################################
df_filtered = df[df["excldate"] >= "2020-12-31"].copy()

# %%
print(f"New Dataset Shape After Filtering for Exclusion Dates: {df_filtered.shape}")
# Out:
# New Dataset Shape After Filtering for Exclusion Dates: (11446, 19)

# %%
###################################
# filter dataset on specified exclusion types
###################################

specified_types = [
    "1128a1", "1128a2", "1128a3",
    "1128b1a", "1128b5", "1128b6", "1128b7",
    "1128c3gi", "1128c3gii",
    "1156",
    "brch cia"
]

df_filtered = df_filtered[df_filtered["excltype"].isin([x.lower() for x in specified_types])]

# %%
print(f"New Dataset Shape After Filtering for Exclusion Types: {df_filtered.shape}")
# Out:
# New Dataset Shape After Filtering for Exclusion Types: (7182, 19)

# %%
# Create Unique ID for each row

id_cols = ["firstname", "lastname", "busname", "dob"]

df_filtered.loc[:, "new_id"]  = df_filtered[id_cols].astype(str).agg("-".join, axis=1)

# %%
###################################
# filter dataset on most recent exclusion only to get 1 per row
###################################

# Sort so most recent date is first
df_filtered = df_filtered.sort_values(["new_id", "excldate"], ascending=[True, False])

# Keep only the most recent row per ID
df_filtered = df_filtered.groupby("new_id", as_index=False).head(1)

# %%
##############################################################
# Return a dataset that has null NPIs to possibly add to later
##############################################################
df_with_null_npi = df_filtered

df_with_null_npi.to_csv("/dsa/groups/casestudycf25/team02/leie_with_null_npi_clean.csv", index=False)
df_with_null_npi.shape
# Out:
# (7159, 20)

# %%
# Check the newly created CSV
temp = pd.read_csv("/dsa/groups/casestudycf25/team02/leie_with_null_npi_clean.csv")

temp.shape
# Out:
# (7159, 20)

# %%
###################################
# filter dataset where there is only valid NPIs., exclude nulls
###################################
df_valid_npi = df_filtered[df_filtered["npi"].notna()].copy()

# %%
print("Check if there are any duplicate NPIs in final dataset: ")
df_valid_npi["npi"].duplicated().any()
# Out:
# Check if there are any duplicate NPIs in final dataset:
# False

# %%
print(f"New Dataset Shape After Filtering for Valid NPIs: {df_valid_npi.shape}")
# Out:
# New Dataset Shape After Filtering for Valid NPIs: (1739, 20)

# %%
# Add in fraud flag where every row is 1
df_valid_npi.loc[:, "fraud_flag"] = 1

# %%
type_dummies = pd.get_dummies(df_valid_npi["excltype"], prefix="excl")

# Attach back to df
df_valid_npi = df_valid_npi.join(type_dummies)

# %%
df_valid_npi.drop(columns = ["lastname" , "firstname" , "midname" , "busname", 
                            "dob","upin",
                             "address", "city", "state", "zip"], inplace = True)

# %%
df_valid_npi.head(1)
# Out:
#                     general specialty           npi excltype   excldate  \
# 76821  IND- LIC HC SERV PRO   DENTIST  1.861529e+09   1128a3 2024-03-20
#
#        num_exclusions_alltime  num_exclusion_types_alltime  \
# 76821                     1.0                          1.0
#
#       list_exclusion_types_alltime  num_addresses_alltime  \
# 76821                     [1128a3]                    1.0
#
#                            new_id  fraud_flag  excl_1128a1  excl_1128a2  \
# 76821  AAMIR-WAHAB-nan-1979-11-16           1        False        False
#
#        excl_1128a3  excl_1128b5  excl_1128b6  excl_1128b7  excl_brch cia
# 76821         True        False        False        False          False

# %%
col_totals = df_valid_npi.select_dtypes(include="number").sum()
print("All Column Totals")
print("-" *50)
print(col_totals.apply(lambda x: f"{x:.0f}"))
# Out:
# All Column Totals
# --------------------------------------------------
# npi                            2601040220059
# num_exclusions_alltime                  1793
# num_exclusion_types_alltime             1775
# num_addresses_alltime                   1787
# fraud_flag                              1739
# dtype: object

# %%
##############################################################
# Return a dataset that is clean for modeling use
##############################################################

df_valid_npi.to_csv("/dsa/groups/casestudycf25/team02/leie_with_valid_npi_clean.csv", index=False)
df_valid_npi.shape
# Out:
# (1739, 18)

# %%
# Check the newly created CSV
temp = pd.read_csv("/dsa/groups/casestudycf25/team02/leie_with_valid_npi_clean.csv")

temp.shape
# Out:
# (1739, 18)
