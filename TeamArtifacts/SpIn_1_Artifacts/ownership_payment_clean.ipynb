# %%
# Packages
import numpy as np
import pandas as pd
import glob

# %%
#The Ownership dataset (2021-2023)
df = pd.read_csv("/dsa/groups/casestudycf25/team02/OWNRSHP_PGYR2021_2023.csv")
df.head(5)
# Out:
#   Change_Type  Physician_Profile_ID  Physician_NPI Physician_First_Name  \
# 0   UNCHANGED                361157   1.962476e+09              Marlene
# 1   UNCHANGED                173155   1.821079e+09               Robert
# 2         NEW                 84927   1.881709e+09            andreluiz
# 3         NEW                119199   1.639176e+09              shephal
# 4         NEW                233626   1.144259e+09             srinivas
#
#   Physician_Middle_Name Physician_Last_Name Physician_Name_Suffix  \
# 0                   NaN              Moster                   NaN
# 1                   NaN               Ritch                   NaN
# 2                   NaN              davila                   NaN
# 3                   NaN               doshi                   NaN
# 4                   NaN           dukkipati                   NaN
#
#   Recipient_Primary_Business_Street_Address_Line1  \
# 0                            100 Presidential Bvd
# 1                               455 W 57th Street
# 2                                185 pilgrim road
# 3                          2001 santa monica blvd
# 4                          1 gustav l. levy place
#
#   Recipient_Primary_Business_Street_Address_Line2 Recipient_City  ...  \
# 0                                       Suite 200    Bala Cynwyd  ...
# 1                                             NaN       New York  ...
# 2                                          baker4         Boston  ...
# 3                                         ste280w   santa monica  ...
# 4                                             NaN       new york  ...
#
#   Value_of_Interest            Terms_of_Interest  \
# 0            296.69  Equity Distribution payment
# 1            593.37  Equity Distribution payment
# 2          31926.00               private equity
# 3          43161.00               private equity
# 4          87984.00               private equity
#
#   Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name  \
# 0                           Mobius Therapeutics, LLC
# 1                           Mobius Therapeutics, LLC
# 2                      Manual Surgical Sciences, LLC
# 3                      Manual Surgical Sciences, LLC
# 4                      Manual Surgical Sciences, LLC
#
#   Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID  \
# 0                                       100000011188
# 1                                       100000011188
# 2                                       100000806858
# 3                                       100000806858
# 4                                       100000806858
#
#    Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name  \
# 0                           Mobius Therapeutics, LLC
# 1                           Mobius Therapeutics, LLC
# 2                      Manual Surgical Sciences, LLC
# 3                      Manual Surgical Sciences, LLC
# 4                      Manual Surgical Sciences, LLC
#
#   Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State  \
# 0                                                 MO
# 1                                                 MO
# 2                                                 UT
# 3                                                 UT
# 4                                                 UT
#
#   Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country  \
# 0                                      United States
# 1                                      United States
# 2                                      United States
# 3                                      United States
# 4                                      United States
#
#    Dispute_Status_for_Publication  \
# 0                              No
# 1                              No
# 2                              No
# 3                              No
# 4                              No
#
#    Interest_Held_by_Physician_or_an_Immediate_Family_Member  \
# 0                        Physician Covered Recipient
# 1                        Physician Covered Recipient
# 2                        Physician Covered Recipient
# 3                        Physician Covered Recipient
# 4                        Physician Covered Recipient
#
#    Payment_Publication_Date
# 0                 6/30/2025
# 1                 6/30/2025
# 2                 6/30/2025
# 3                 6/30/2025
# 4                 6/30/2025
#
# [5 rows x 30 columns]

# %%
df["Record_ID"].head(5)
# Out:
# 0    754966674
# 1    754966682
# 2    755268702
# 3    755300384
# 4    755306684
# Name: Record_ID, dtype: int64

# %%
#Shape and Columns of Ownership Datasets
print(df.shape)
print(df.columns)
df.info()
# Out:
# (12710, 30)
# Index(['Change_Type', 'Physician_Profile_ID', 'Physician_NPI',
#        'Physician_First_Name', 'Physician_Middle_Name', 'Physician_Last_Name',
#        'Physician_Name_Suffix',
#        'Recipient_Primary_Business_Street_Address_Line1',
#        'Recipient_Primary_Business_Street_Address_Line2', 'Recipient_City',
#        'Recipient_State', 'Recipient_Zip_Code', 'Recipient_Country',
#        'Recipient_Province', 'Recipient_Postal_Code', 'Physician_Primary_Type',
#        'Physician_Specialty', 'Record_ID', 'Program_Year',
#        'Total_Amount_Invested_USDollars', 'Value_of_Interest',
#        'Terms_of_Interest',
#        'Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State',
#        'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country',
#        'Dispute_Status_for_Publication',
#        'Interest_Held_by_Physician_or_an_Immediate_Family_Member',
#        'Payment_Publication_Date'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12710 entries, 0 to 12709
# Data columns (total 30 columns):
# Change_Type                                                         12710 non-null object
# Physician_Profile_ID                                                12710 non-null int64
# Physician_NPI                                                       12702 non-null float64
# Physician_First_Name                                                12710 non-null object
# Physician_Middle_Name                                               4282 non-null object
# Physician_Last_Name                                                 12710 non-null object
# Physician_Name_Suffix                                               595 non-null object
# Recipient_Primary_Business_Street_Address_Line1                     12710 non-null object
# Recipient_Primary_Business_Street_Address_Line2                     5677 non-null object
# Recipient_City                                                      12710 non-null object
# Recipient_State                                                     12709 non-null object
# Recipient_Zip_Code                                                  12709 non-null object
# Recipient_Country                                                   12710 non-null object
# Recipient_Province                                                  1 non-null object
# Recipient_Postal_Code                                               1 non-null float64
# Physician_Primary_Type                                              12710 non-null object
# Physician_Specialty                                                 12710 non-null object
# Record_ID                                                           12710 non-null int64
# Program_Year                                                        12710 non-null int64
# Total_Amount_Invested_USDollars                                     12710 non-null float64
# Value_of_Interest                                                   12710 non-null float64
# Terms_of_Interest                                                   12685 non-null object
# Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name           12710 non-null object
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID         12710 non-null int64
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name       12710 non-null object
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State      12587 non-null object
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country    12710 non-null object
# Dispute_Status_for_Publication                                      12710 non-null object
# Interest_Held_by_Physician_or_an_Immediate_Family_Member            12710 non-null object
# Payment_Publication_Date                                            12710 non-null object
# dtypes: float64(4), int64(4), object(22)
# memory usage: 2.9+ MB

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Recipient_Postal_Code                                               12709
# Recipient_Province                                                  12709
# Physician_Name_Suffix                                               12115
# Physician_Middle_Name                                                8428
# Recipient_Primary_Business_Street_Address_Line2                      7033
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State        123
# Terms_of_Interest                                                      25
# Physician_NPI                                                           8
# Recipient_State                                                         1
# Recipient_Zip_Code                                                      1
# Physician_Profile_ID                                                    0
# Physician_First_Name                                                    0
# Physician_Last_Name                                                     0
# Recipient_Primary_Business_Street_Address_Line1                         0
# Recipient_City                                                          0
# Recipient_Country                                                       0
# Payment_Publication_Date                                                0
# Interest_Held_by_Physician_or_an_Immediate_Family_Member                0
# Physician_Primary_Type                                                  0
# Physician_Specialty                                                     0
# Record_ID                                                               0
# Program_Year                                                            0
# Total_Amount_Invested_USDollars                                         0
# Value_of_Interest                                                       0
# Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name               0
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID             0
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name           0
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country        0
# Dispute_Status_for_Publication                                          0
# Change_Type                                                             0
# dtype: int64

# %%
#Fixing the NPI formatting
# Convert Ownership NPI to string without scientific notation
df["Physician_NPI"] = df["Physician_NPI"].astype("Int64").astype(str)

#Standardize Names for Matching
df["FULL_NAME"] = (
    df["Physician_First_Name"].str.strip().str.upper() + " " +
    df["Physician_Last_Name"].str.strip().str.upper()
)

# %%
# Remove numbers after the dash in the zipcode column. Example 37212-4354 -> 37212
df["Recipient_Zip_Code"] = df["Recipient_Zip_Code"].str.replace(r"-\d{4}$", "", regex=True)

# %%
# Any column that contains 'Name' is trimmed and uppercased
print(df['FULL_NAME'].head(1))
cols = [c for c in df.columns if "name" in c.lower()]

df[cols] = df[cols].apply(lambda col: col.str.upper().str.strip())
df['FULL_NAME'].head(1)
# Out:
# 0    MARLENE MOSTER
# Name: FULL_NAME, dtype: object
# 0    MARLENE MOSTER
# Name: FULL_NAME, dtype: object

# %%
# Terms_of_Interest is trimmed and uppercased
print(df['Terms_of_Interest'].head(1))

df["Terms_of_Interest"] = df["Terms_of_Interest"].str.upper().str.strip()
df['Terms_of_Interest'].head(1)
# Out:
# 0    Equity Distribution payment
# Name: Terms_of_Interest, dtype: object
# 0    EQUITY DISTRIBUTION PAYMENT
# Name: Terms_of_Interest, dtype: object

# %%
# Check blank rows in manufacturer name
blank_rows = df[df["FULL_NAME"]
                  .astype(str).str.strip().eq("")]
blank_rows
# Out:
# Empty DataFrame
# Columns: [Change_Type, Physician_Profile_ID, Physician_NPI, Physician_First_Name, Physician_Middle_Name, Physician_Last_Name, Physician_Name_Suffix, Recipient_Primary_Business_Street_Address_Line1, Recipient_Primary_Business_Street_Address_Line2, Recipient_City, Recipient_State, Recipient_Zip_Code, Recipient_Country, Recipient_Province, Recipient_Postal_Code, Physician_Primary_Type, Physician_Specialty, Record_ID, Program_Year, Total_Amount_Invested_USDollars, Value_of_Interest, Terms_of_Interest, Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name, Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID, Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name, Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State, Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country, Dispute_Status_for_Publication, Interest_Held_by_Physician_or_an_Immediate_Family_Member, Payment_Publication_Date, FULL_NAME]
# Index: []
#
# [0 rows x 31 columns]

# %%
###################
# Drop blank columns
#####################
df.dropna(axis=1, how="all", inplace=True)

# %%
###################################
# filter dataset to remove Nas in Physician_NPI
###################################
df = df.dropna(subset=["Physician_NPI"])

# %%
df['Dispute_Status_for_Publication'].value_counts()
# Out:
# No     12708
# Yes        2
# Name: Dispute_Status_for_Publication, dtype: int64

# %%
###################################
# filter dataset to remove disputed ownership records
###################################

df_filtered = df[df["Dispute_Status_for_Publication"] == "No"]

# %%
#####################
# Drop unrelated columns
#####################
drop_cols = [
    
    # unnecessary because it is in other dataset
    'Physician_First_Name', 'Physician_Middle_Name', 'Physician_Last_Name',
    'Physician_Name_Suffix',
    'Recipient_Primary_Business_Street_Address_Line1',
    'Recipient_Primary_Business_Street_Address_Line2', 'Recipient_City',
    'Recipient_State', 'Recipient_Zip_Code', 'Recipient_Country',
    'Recipient_Province', 'Recipient_Postal_Code', 'Physician_Primary_Type',
    'Physician_Specialty',   
    
    # unnecessary because it is in other dataset
    'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country'  ,    
    'Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name'  # using application name instead
]

df = df.drop(columns=drop_cols)

# %%
print(f"New Dataset Shape After Dropping Cols: {df.shape}")
# Out:
# New Dataset Shape After Dropping Cols: (12710, 15)

# %%
###################################
# Check for any duplicate record
###################################
print("Check if there are any duplicate record ids in final dataset: ")
df["Record_ID"].duplicated().any()
# Out:
# Check if there are any duplicate record ids in final dataset:
# False

# %%
col_totals = df.select_dtypes(include="number").sum()
print("All Column Totals")
print("-" *50)
print(col_totals.apply(lambda x: f"{x:.0f}"))
# Out:
# All Column Totals
# --------------------------------------------------
# Physician_Profile_ID                                                 6414412036
# Record_ID                                                        11934425509635
# Program_Year                                                           25699747
# Total_Amount_Invested_USDollars                                       936165817
# Value_of_Interest                                                    4111446123
# Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID    1271005988744339
# dtype: object

# %%
df.to_csv("/dsa/groups/casestudycf25/team02/ownership_payment_clean.csv", index=False)
df_filtered.shape
# Out:
# (12708, 31)

# %%
df.to_csv("ownership_payment_clean.csv", index=False)
