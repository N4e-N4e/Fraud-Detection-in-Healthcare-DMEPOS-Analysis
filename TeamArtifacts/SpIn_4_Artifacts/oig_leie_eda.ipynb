# %% [markdown]
# # LEIE EDA
#
# This script uses the raw LEIE_OIG_Exclusion_List.csv for exploratory data vizes.

# %%
# Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import re

def to_snake_case(name: str) -> str:
    # Add underscore between lower-to-upper transitions
    name = re.sub(r'(.)([A-Z][a-z]+)', r'\1_\2', name)
    name = re.sub(r'([a-z0-9])([A-Z])', r'\1_\2', name)

    # Replace non-alphanumeric with underscores
    name = re.sub(r'[^0-9a-zA-Z]+', '_', name)

    # Remove leading/trailing underscores and lowercase
    return name.strip("_").lower()

# %%
df = pd.read_csv("/dsa/groups/casestudycf25/team02/LEIE_OIG_Exclusion_List.csv")

df = df.rename(columns={col: to_snake_case(col) for col in df.columns})

# Convert to datetime
df["excldate"] = pd.to_datetime(df["excldate"], format="%Y%m%d")

# Convert to datetime
df["npi"] = df["npi"].to_numpy(int)

df.head(5)
# Out:
# /tmp/ipykernel_4606/1025496247.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/dsa/groups/casestudycf25/team02/LEIE_OIG_Exclusion_List.csv")
#   lastname firstname midname                      busname         general  \
# 0      NaN       NaN     NaN    #1 MARKETING SERVICE, INC  OTHER BUSINESS
# 1      NaN       NaN     NaN             1 BEST CARE, INC  OTHER BUSINESS
# 2      NaN       NaN     NaN  101 FIRST CARE PHARMACY INC  OTHER BUSINESS
# 3      NaN       NaN     NaN     14 LAWRENCE AVE PHARMACY        PHARMACY
# 4      NaN       NaN     NaN     143 MEDICAL EQUIPMENT CO     DME COMPANY
#
#             specialty upin         npi  dob                        address  \
# 0          SOBER HOME  NaN           0  NaN      239 BRIGHTON BEACH AVENUE
# 1  HOME HEALTH AGENCY  NaN           0  NaN  2161 UNIVERSITY AVENUE W, STE
# 2            PHARMACY  NaN  1972902351  NaN  C/O 609 W 191ST STREET, APT D
# 3                 NaN  NaN           0  NaN             14 LAWRENCE AVENUE
# 4        DME - OXYGEN  NaN           0  NaN               701 NW 36 AVENUE
#
#          city state    zip excltype   excldate  reindate  waiverdate wvrstate
# 0    BROOKLYN    NY  11235   1128a1 2020-03-19         0           0      NaN
# 1  SAINT PAUL    MN  55114   1128b5 2023-05-18         0           0      NaN
# 2    NEW YORK    NY  10040   1128b8 2022-03-20         0           0      NaN
# 3   SMITHTOWN    NY  11787   1128a1 1988-08-30         0           0      NaN
# 4       MIAMI    FL  33125   1128b7 1997-06-20         0           0      NaN

# %%
df.shape
# Out:
# (81991, 18)

# %%
no_npis = df[df["npi"] > 0]

display(no_npis.head(4))

print(f"Total rows: {no_npis.shape[0]}")
# Out:
#    lastname firstname midname                      busname         general  \
# 2       NaN       NaN     NaN  101 FIRST CARE PHARMACY INC  OTHER BUSINESS
# 6       NaN       NaN     NaN   184TH STREET PHARMACY CORP  OTHER BUSINESS
# 26      NaN       NaN     NaN    A & Y MEDICAL SUPPLY, INC     DME COMPANY
# 30      NaN       NaN     NaN    A CARING ALTERNATIVE, INC  OTHER BUSINESS
#
#              specialty upin         npi  dob                        address  \
# 2             PHARMACY  NaN  1972902351  NaN  C/O 609 W 191ST STREET, APT D
# 6             PHARMACY  NaN  1922348218  NaN                  69 E 184TH ST
# 26       DME - GENERAL  NaN  1942476080  NaN      6310 108TH STREET, APT 6J
# 30  HOME HEALTH AGENCY  NaN  1275600959  NaN       1229 HURON RD E, FLR 6TH
#
#             city state    zip excltype   excldate  reindate  waiverdate  \
# 2       NEW YORK    NY  10040   1128b8 2022-03-20         0           0
# 6          BRONX    NY  10468   1128a1 2018-04-19         0           0
# 26  FOREST HILLS    NY  11375   1128b8 2017-05-18         0           0
# 30     CLEVELAND    OH  44115   1128a1 2013-03-20         0           0
#
#    wvrstate
# 2       NaN
# 6       NaN
# 26      NaN
# 30      NaN
# Total rows: 8263

# %%
no_npis[no_npis["excldate"] >= "2021-01-01"].shape
# Out:
# (3039, 18)

# %%
plt.hist(no_npis["excldate"], bins=30)
# Out:
# (array([2.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 2.000e+00, 3.000e+00,
#         3.000e+00, 1.000e+00, 5.000e+00, 8.000e+00, 4.000e+00, 3.000e+00,
#         5.000e+00, 4.000e+00, 1.100e+01, 1.300e+01, 1.840e+02, 3.770e+02,
#         3.440e+02, 4.440e+02, 5.600e+02, 6.360e+02, 6.640e+02, 7.080e+02,
#         5.680e+02, 5.250e+02, 5.090e+02, 8.030e+02, 8.450e+02, 1.031e+03]),
#  array([ 6758.        ,  7211.03333333,  7664.06666667,  8117.1       ,
#          8570.13333333,  9023.16666667,  9476.2       ,  9929.23333333,
#         10382.26666667, 10835.3       , 11288.33333333, 11741.36666667,
#         12194.4       , 12647.43333333, 13100.46666667, 13553.5       ,
#         14006.53333333, 14459.56666667, 14912.6       , 15365.63333333,
#         15818.66666667, 16271.7       , 16724.73333333, 17177.76666667,
#         17630.8       , 18083.83333333, 18536.86666667, 18989.9       ,
#         19442.93333333, 19895.96666667, 20349.        ]),
#  <BarContainer object of 30 artists>)

# %%
specialties = pd.DataFrame(no_npis["specialty"].value_counts())

specialties = specialties.head(10)

specialties = specialties.reset_index().rename(columns={"index": "specialty", "count": "count"}).sort_values(by="count", ascending=True)

plt.barh(specialties["specialty"], specialties["count"], color='skyblue')
# Out:
# <BarContainer object of 10 artists>

# %%
generals = pd.DataFrame(no_npis["general"].value_counts())

generals = generals.head(10)

generals = generals.reset_index().rename(columns={"index": "general", "count": "count"}).sort_values(by="count", ascending=True)

plt.barh(generals["general"], generals["count"], color='pink')
# Out:
# <BarContainer object of 10 artists>

# %%
states = pd.DataFrame(no_npis["state"].value_counts())

states = states.reset_index().rename(columns={"index": "state", "count": "count"}).sort_values(by="count", ascending=True)

# %%
# !pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-1.1.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy>=1.24 in /opt/conda/lib/python3.12/site-packages (from geopandas) (1.26.4)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.12.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (5.9 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from geopandas) (2.3.2)
# Collecting pyproj>=3.5.0 (from geopandas)
#   Downloading pyproj-3.7.2-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.1.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from pyogrio>=0.7.2->geopandas) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Downloading geopandas-1.1.1-py3-none-any.whl (338 kB)
# Downloading pyogrio-0.12.1-cp312-cp312-manylinux_2_28_x86_64.whl (32.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.5/32.5 MB 134.4 MB/s  0:00:00m0:00:01
# Downloading pyproj-3.7.2-cp312-cp312-manylinux_2_28_x86_64.whl (9.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 165.7 MB/s  0:00:00
# Downloading shapely-2.1.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 131.1 MB/s  0:00:00
# Installing collected packages: shapely, pyproj, pyogrio, geopandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [geopandas]/4 [geopandas]
# Successfully installed geopandas-1.1.1 pyogrio-0.12.1 pyproj-3.7.2 shapely-2.1.2

# %%
import geopandas as gpd

# A common source is census shapefiles via `geopandas` + `requests`
states_load = gpd.read_file("https://www2.census.gov/geo/tiger/GENZ2018/shp/cb_2018_us_state_20m.zip")

states_load = states_load[~states_load['STUSPS'].isin(["PR", "GU", "VI", "MP", "AS"])]

# %%
# Merge abbreviation-based df with shapefile
states_load = states_load.rename(columns={"STUSPS": "state"})  # STUSPS = state abbreviation
merged = states_load.merge(states, on="state", how="left")

# Project to equal-area CRS for cleaner plotting
merged = merged.to_crs(epsg=2163)

# %%
# Plot map
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
merged.plot(column="count", cmap="Blues", ax = ax, linewidth=0.8, edgecolor="0.8", legend=True)
# Out:
# <Axes: >
